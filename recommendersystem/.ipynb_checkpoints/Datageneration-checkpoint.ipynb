# %% [markdown]
# # Fake data generation

# %%
from faker import Faker
import numpy as np
import pandas as pd
import random

# %%
faker = Faker(seed=666)
np.random.seed(666)

# %%
keywords = [
    'archeology',
    'museums',
    'music',
    'art',
    'cinema',
    'countryside',
    'tracking',
    'rafting',
    'history',
    'literature',
    'sport',
    'food',
    'wine',
    'beer'
]

# %%
# guide profile generation
def generate_guide():
    guide = {}
    guide['gender'] = np.random.choice(['male', 'female'], size=1).item()
    guide['name'] = (faker.first_name_male() if guide['gender'] == 'male' else faker.first_name_female()) + ' ' + faker.last_name()
    guide['birth_date'] = faker.date_of_birth(maximum_age=65, minimum_age=20)
    guide['now_available'] = True
    guide['languages_spoken'] = list(np.random.choice(['english', 'italian', 'french', 'spanish', 'deutsche', 'dutch', 'bulgarian', 'chinese'], size=1+np.random.poisson(lam=1, size=1).item(), replace=False))
    guide['price'] = int(max(10, np.abs(np.random.normal(30, 5))))
    guide['education'] = np.random.choice(['middle-school', 'high-school', 'bachelor', 'master', 'phd'], size=1).item()
    guide['biography'] = faker.profile()['job']
    guide['keywords'] = list(np.random.choice(keywords, size=np.random.poisson(2, size=1).item(), replace=False))
    guide['current_location'] = {
        "lat": np.random.normal(40.3524, 0.01),
        "lon": np.random.normal(18.1732, 0.01)
    }
    guide['experience'] = random.randint(1,2024-guide['birth_date'].year-18)
    
    return guide

# %%
# user profile generation
def generate_tourist():

    tourist = {}

    tourist['languages'] = list(np.random.choice(['english', 'italian', 'french', 'spanish', 'deutsche', 'dutch', 'bulgarian', 'chinese'], size=1, replace=False))

    tourist['keywords'] = list(np.random.choice(keywords, size=np.random.poisson(2, size=1).item(), replace=False))
    
    return tourist

# %%
import random 

# rating generation
def generate_rating (tourists, guides):
    ratings = []
    for i in range(len(tourists)):
        
        # random choose guides from intersection of languages
        intersect_guides = [index for index in range(len(guides)) if np.all(np.in1d(tourists[i]['languages'], guides[index]['languages_spoken']))]
        other_guides = [index for index in range(len(guides)) if index not in intersect_guides]
        
        # random choose 3 guides without duplicates
        random_guides = np.random.choice(intersect_guides,2, replace=False)
        random_guide = np.random.choice(other_guides,1)
        
        # random choose 1 or 2 guides to rate
        for j in range(np.random.randint(1,3)):

            rating = round(np.random.normal(loc=4, scale=0.5, size=1).item(),0)
            ratings.append((i,random_guides[j],rating))

        # random choose if rate badly
#        if(np.random.binomial(1, 0.2)):
            bad_rating = round(np.random.normal(loc=1.5, scale=0.3, size=1).item(),0)
            # rate the last guide with bad rating
            ratings.append((i,random_guide[0],bad_rating))
    
    return ratings

# %% [markdown]
# #### Data generation

# %%
n_tourists = 200
n_guides = 40

# %%
guides = [generate_guide() for _ in range(n_guides)]
tourists = [generate_tourist() for _ in range(n_tourists)]

# %%
ratings = generate_rating(tourists,guides)

# %% [markdown]
# Dataframes

# %%
guide_df = pd.DataFrame(guides)
guide_df
# Out:
#     gender                 name  birth_date  now_available  \
# 0     male       Charles Martin  1971-03-25           True
# 1   female        Rachel Carter  2002-02-19           True
# 2   female         Lynn Goodman  1982-03-25           True
# 3     male         Shawn Patton  1962-06-01           True
# 4     male         Joseph Reyes  1964-05-12           True
# 5     male        James Ramirez  1993-10-26           True
# 6     male         Shaun Morrow  1976-12-08           True
# 7     male      William Coleman  2004-01-02           True
# 8     male          Keith Knapp  1987-10-16           True
# 9     male       Bill Hernandez  1963-12-01           True
# 10  female           Karen Bell  2002-05-23           True
# 11  female            Tammy Lee  2003-06-16           True
# 12  female           Monica Lee  2003-07-04           True
# 13  female        Kathleen Hill  1958-09-10           True
# 14    male       Michael Ritter  1967-03-20           True
# 15    male           Erik Roach  1961-03-30           True
# 16    male     Preston Gonzales  1982-08-23           True
# 17    male      Elijah Sullivan  1994-01-05           True
# 18    male           Joel Wells  1993-08-21           True
# 19  female        Kelly Collins  1988-12-11           True
# 20  female     Courtney Johnson  1963-12-13           True
# 21    male       David Woodward  1961-06-11           True
# 22  female            Amy Riley  1958-12-21           True
# 23  female         Audrey Burch  1992-02-16           True
# 24  female        Samantha Pena  1974-05-16           True
# 25  female    Katherine Summers  1977-03-17           True
# 26    male       Jeffrey Brooks  2002-06-04           True
# 27  female      Deborah Jimenez  1974-09-01           True
# 28  female      Andrea Thompson  1973-06-11           True
# 29  female         Sharon Mccoy  1998-06-14           True
# 30  female         Tracy Fuller  1972-02-21           True
# 31    male  Christopher Shields  1984-11-06           True
# 32  female           Amy Garcia  2002-05-09           True
# 33    male         Joshua Casey  1980-05-18           True
# 34  female      Erika Mccormick  1966-01-26           True
# 35    male          Craig Grant  1973-03-16           True
# 36    male         Javier Smith  2003-07-06           True
# 37    male          David Payne  1983-04-23           True
# 38  female         Jackie Gomez  1986-12-17           True
# 39  female         Sarah Martin  1967-06-10           True
#
#                           languages_spoken  price      education  \
# 0                                [english]     25    high-school
# 1                         [italian, dutch]     36  middle-school
# 2               [chinese, french, english]     34            phd
# 3                              [bulgarian]     46       bachelor
# 4                       [deutsche, french]     30         master
# 5             [deutsche, dutch, bulgarian]     27  middle-school
# 6               [english, chinese, french]     34  middle-school
# 7        [spanish, dutch, french, italian]     33       bachelor
# 8            [bulgarian, english, chinese]     31  middle-school
# 9     [chinese, bulgarian, dutch, english]     37            phd
# 10                   [bulgarian, deutsche]     23    high-school
# 11                             [bulgarian]     23            phd
# 12                [dutch, french, italian]     19       bachelor
# 13                      [chinese, english]     27         master
# 14                       [chinese, french]     40  middle-school
# 15                     [deutsche, chinese]     31  middle-school
# 16            [spanish, bulgarian, french]     32  middle-school
# 17                                 [dutch]     26         master
# 18                        [italian, dutch]     24       bachelor
# 19          [bulgarian, deutsche, english]     35  middle-school
# 20                      [deutsche, french]     43         master
# 21                               [chinese]     26    high-school
# 22                      [chinese, spanish]     25    high-school
# 23           [english, italian, bulgarian]     20  middle-school
# 24             [dutch, italian, bulgarian]     28    high-school
# 25                             [bulgarian]     31            phd
# 26                                 [dutch]     30            phd
# 27                               [italian]     30            phd
# 28                               [spanish]     25  middle-school
# 29                    [bulgarian, chinese]     28         master
# 30             [french, deutsche, english]     27       bachelor
# 31             [deutsche, french, english]     23         master
# 32                     [french, bulgarian]     28            phd
# 33                                [french]     26  middle-school
# 34  [chinese, spanish, bulgarian, italian]     28  middle-school
# 35                       [italian, french]     30         master
# 36                               [spanish]     26            phd
# 37                                 [dutch]     26         master
# 38                               [italian]     28         master
# 39                        [spanish, dutch]     26  middle-school
#
#                                        biography  \
# 0                         Occupational hygienist
# 1                                  Airline pilot
# 2                             Wellsite geologist
# 3                        Scientist, audiological
# 4                                   Neurosurgeon
# 5                                       Musician
# 6                    Careers information officer
# 7                                  Social worker
# 8                                    Proofreader
# 9                               Network engineer
# 10                   Civil Service administrator
# 11                           Dispensing optician
# 12        Scientist, product/process development
# 13                              Fashion designer
# 14                               Charity officer
# 15                                          Copy
# 16                   Passenger transport manager
# 17                   Health promotion specialist
# 18                                Chief of Staff
# 19                             Fish farm manager
# 20        Research scientist (physical sciences)
# 21                           Associate Professor
# 22                               Tourism officer
# 23                               Equities trader
# 24                         Aeronautical engineer
# 25                              Location manager
# 26                         Adult guidance worker
# 27                       Diagnostic radiographer
# 28                                  Toxicologist
# 29                  Fast food restaurant manager
# 30  Production designer, theatre/television/film
# 31                        Therapist, nutritional
# 32                   Information systems manager
# 33                      Educational psychologist
# 34                                  Statistician
# 35                         Forensic psychologist
# 36              Psychologist, sport and exercise
# 37                      Plant breeder/geneticist
# 38                       Chief Financial Officer
# 39                                    Ergonomist
#
#                                              keywords  \
# 0                                           [museums]
# 1                    [cinema, rafting, history, wine]
# 2                             [food, archeology, art]
# 3                         [countryside, rafting, art]
# 4                       [countryside, tracking, beer]
# 5                                                  []
# 6                               [rafting, art, sport]
# 7                   [museums, art, countryside, wine]
# 8                         [literature, cinema, music]
# 9                                           [museums]
# 10     [cinema, rafting, sport, museums, countryside]
# 11                            [cinema, beer, rafting]
# 12                               [sport, music, beer]
# 13                          [sport, archeology, beer]
# 14                                          [museums]
# 15                [music, food, tracking, archeology]
# 16                         [countryside, music, beer]
# 17                                 [wine, sport, art]
# 18                                             [food]
# 19                                                 []
# 20                           [rafting, museums, food]
# 21                                           [cinema]
# 22  [history, countryside, cinema, literature, music]
# 23                                         [tracking]
# 24                                                 []
# 25                                       [literature]
# 26                          [tracking, beer, museums]
# 27                                [countryside, beer]
# 28     [food, rafting, museums, music, art, tracking]
# 29                 [archeology, literature, tracking]
# 30                                            [music]
# 31                         [music, countryside, food]
# 32                                [archeology, music]
# 33             [beer, music, countryside, archeology]
# 34                                                 []
# 35                                            [music]
# 36                                                 []
# 37                                                 []
# 38                                                 []
# 39                                          [history]
#
#                                      current_location  experience
# 0   {'lat': 40.342693584880706, 'lon': 18.16438078...          20
# 1   {'lat': 40.3367551413547, 'lon': 18.1569120995...           1
# 2   {'lat': 40.362447049660204, 'lon': 18.14225129...          15
# 3   {'lat': 40.36584086550253, 'lon': 18.183002910...           6
# 4   {'lat': 40.354724889812935, 'lon': 18.20308322...          24
# 5   {'lat': 40.35854623058413, 'lon': 18.183459879...           8
# 6   {'lat': 40.35774331848761, 'lon': 18.163273185...          21
# 7   {'lat': 40.365193043282794, 'lon': 18.18548169...           2
# 8   {'lat': 40.35265552781134, 'lon': 18.151723396...          11
# 9   {'lat': 40.33774657696426, 'lon': 18.182064664...          20
# 10  {'lat': 40.36612881009787, 'lon': 18.182042843...           3
# 11  {'lat': 40.367394960036485, 'lon': 18.17553586...           3
# 12  {'lat': 40.34268462008425, 'lon': 18.187542175...           3
# 13  {'lat': 40.35377358678542, 'lon': 18.174728239...           6
# 14  {'lat': 40.353069674191346, 'lon': 18.17755576...          13
# 15  {'lat': 40.35272705494921, 'lon': 18.165705019...          24
# 16  {'lat': 40.32347428820915, 'lon': 18.164571467...          10
# 17  {'lat': 40.36624424923941, 'lon': 18.174443383...           8
# 18  {'lat': 40.362871505646005, 'lon': 18.18292777...           6
# 19  {'lat': 40.339915788807765, 'lon': 18.18379781...          15
# 20  {'lat': 40.357612936236265, 'lon': 18.16907898...           8
# 21  {'lat': 40.342846292499104, 'lon': 18.16089760...          15
# 22  {'lat': 40.36846436096489, 'lon': 18.171263566...          32
# 23  {'lat': 40.364408581391295, 'lon': 18.16428124...           6
# 24  {'lat': 40.32998981194129, 'lon': 18.175342312...           3
# 25  {'lat': 40.36710284805045, 'lon': 18.179956956...          14
# 26  {'lat': 40.37981446263931, 'lon': 18.178854600...           4
# 27  {'lat': 40.3457074414046, 'lon': 18.1747654675...          24
# 28  {'lat': 40.35079556972286, 'lon': 18.181927024...           3
# 29  {'lat': 40.35465462623879, 'lon': 18.172666005...           4
# 30  {'lat': 40.361047668976795, 'lon': 18.18633484...          29
# 31  {'lat': 40.339171732936364, 'lon': 18.16792590...          13
# 32  {'lat': 40.343414579847, 'lon': 18.18565562805...           3
# 33  {'lat': 40.34424559835338, 'lon': 18.174907197...           7
# 34  {'lat': 40.38198340911851, 'lon': 18.173378831...          16
# 35  {'lat': 40.36699713437984, 'lon': 18.165786470...          30
# 36  {'lat': 40.358649720289904, 'lon': 18.16378056...           2
# 37  {'lat': 40.3604075695112, 'lon': 18.1615738690...          10
# 38  {'lat': 40.36497247240833, 'lon': 18.173581152...          12
# 39  {'lat': 40.35901486939172, 'lon': 18.166553513...          16

# %%
guide_df.dtypes
# Out:
# gender              object
# name                object
# birth_date          object
# now_available         bool
# languages_spoken    object
# price                int64
# education           object
# biography           object
# keywords            object
# current_location    object
# experience           int64
# dtype: object

# %%
tourist_df = pd.DataFrame(tourists)
tourist_df
# Out:
#        languages                   keywords
# 0    [bulgarian]                   [cinema]
# 1     [deutsche]                         []
# 2      [spanish]         [rafting, museums]
# 3     [deutsche]    [cinema, history, food]
# 4      [chinese]            [wine, rafting]
# ..           ...                        ...
# 195     [french]                   [cinema]
# 196      [dutch]  [food, tracking, history]
# 197      [dutch]    [museums, art, history]
# 198    [italian]      [rafting, literature]
# 199    [spanish]  [countryside, archeology]
#
# [200 rows x 2 columns]

# %%
rating_df = pd.DataFrame(ratings)

# %%
rating_df
# Out:
#        0   1    2
# 0      0  32  5.0
# 1      0  33  2.0
# 2      0  10  4.0
# 3      0  33  2.0
# 4      1  31  4.0
# ..   ...  ..  ...
# 583  198  16  2.0
# 584  199  36  4.0
# 585  199  26  1.0
# 586  199   7  5.0
# 587  199  26  2.0
#
# [588 rows x 3 columns]

# %%
tourist_df.to_csv("Data/tourists_{:d}.csv".format(n_tourists), index=True, sep=';')
guide_df.to_csv("Data/guides_{:d}.csv".format(n_guides), index=True, sep=';')
rating_df.to_csv('Data/ratings_{:d}_{:d}.csv'.format(n_tourists,n_guides), index=False, sep=';')
