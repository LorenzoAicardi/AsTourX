# %% [markdown]
# ## Fake data generation

# %%
from faker import Faker
import numpy as np
import pandas as pd
import random

# %%
faker = Faker(seed=666)
np.random.seed(666)

# %%
keywords = [
    'archeology',
    'museums',
    'music',
    'art',
    'cinema',
    'countryside',
    'tracking',
    'rafting',
    'history',
    'literature',
    'sport',
    'food',
    'wine',
    'beer'
]

# %%
# guide profile generation
def generate_guide():
    guide = {}
    guide['gender'] = np.random.choice(['male', 'female'], size=1).item()
    guide['name'] = (faker.first_name_male() if guide['gender'] == 'male' else faker.first_name_female()) + ' ' + faker.last_name()
    guide['birth_date'] = faker.date_of_birth(maximum_age=65, minimum_age=20)
    guide['now_available'] = True
    guide['languages_spoken'] = list(np.random.choice(['english', 'italian', 'french', 'spanish', 'deutsche', 'dutch', 'bulgarian', 'chinese'], size=1+np.random.poisson(lam=1, size=1).item(), replace=False))
    guide['price'] = int(max(10, np.abs(np.random.normal(30, 5))))
    guide['education'] = np.random.choice(['middle-school', 'high-school', 'bachelor', 'master', 'phd'], size=1).item()
    guide['biography'] = faker.profile()['job']
    guide['keywords'] = list(np.random.choice(keywords, size=np.random.poisson(2, size=1).item(), replace=False))
    guide['current_location'] = {
        "lat": np.random.normal(40.3524, 0.01),
        "lon": np.random.normal(18.1732, 0.01)
    }
    guide['experience'] = random.randint(1,2024-guide['birth_date'].year-18)
    
    return guide

# %%
# user profile generation
def generate_tourist():

    tourist = {}

    tourist['languages'] = list(np.random.choice(['english', 'italian', 'french', 'spanish', 'deutsche', 'dutch', 'bulgarian', 'chinese'], size=1+np.random.binomial(1, 0.2), replace=False))

    tourist['keywords'] = list(np.random.choice(keywords, size=np.random.poisson(2, size=1).item(), replace=False))
    
    return tourist

# %%
import random 

# rating generation
def generate_rating (tourists, guides):
    ratings = []
    for i in range(tourists):
        
        # random choose 3 guides without duplicates
        random_guides = random.sample(range(guides),3)
        
        # random choose 1 or 2 guides to rate
        for j in range(np.random.randint(1,3)):

            rating = round(np.random.normal(loc=4, scale=0.5, size=1).item(),0)
            ratings.append((i,random_guides[j],rating))

        # random choose if rate badly
        if(np.random.binomial(1, 0.2)):
            bad_rating = round(np.random.normal(loc=1.5, scale=0.3, size=1).item(),0)
            # rate the last guide with bad rating
            ratings.append((i,random_guides[len(random_guides)-1],bad_rating))
    
    return ratings

# %% [markdown]
# #### Data generation

# %%
n_tourists = 200
n_guides = 40

# %%
guides = [generate_guide() for _ in range(n_guides)]
tourists = [generate_tourist() for _ in range(n_tourists)]

# %%
ratings = generate_rating(n_tourists,n_guides)

# %% [markdown]
# Dataframes

# %%
guide_df = pd.DataFrame(guides)
guide_df
# Out:
#     gender               name  birth_date  now_available  \
# 0     male         Sean Lewis  1982-10-10           True
# 1   female     Leah Blackwell  1959-10-31           True
# 2   female       Tracey Lopez  1963-09-25           True
# 3     male      Charles Young  1959-06-19           True
# 4     male      David Burgess  1966-09-09           True
# 5     male       Connor Davis  1997-06-04           True
# 6     male        Michael Lee  1966-12-10           True
# 7     male   Derrick Davidson  1998-03-17           True
# 8     male  Christopher Smith  1958-10-09           True
# 9     male       Albert Moore  1973-07-20           True
# 10  female   Patricia Ramirez  1978-09-27           True
# 11  female  Stephanie Hampton  2001-02-13           True
# 12  female   Jennifer Andrews  1986-03-10           True
# 13  female    Nicole Campbell  1964-02-29           True
# 14    male        Shane Riggs  1980-03-24           True
# 15    male        Alan Glover  1970-08-05           True
# 16    male     Jonathan Smith  1959-08-23           True
# 17    male    Michael Ramirez  1977-08-02           True
# 18    male       Andrew Bates  1964-05-06           True
# 19  female      Stacie Potter  1960-10-20           True
# 20  female        Julie Scott  1966-01-25           True
# 21    male    Michael Jackson  1993-11-25           True
# 22  female         Mary Allen  1990-05-01           True
# 23  female     Monica Leonard  1961-07-26           True
# 24  female      Pamela Turner  1971-12-27           True
# 25  female       Sandra Owens  1980-10-16           True
# 26    male       Julian Lopez  1958-06-11           True
# 27  female       Sheena Bryan  2002-05-29           True
# 28  female     Jennifer Hardy  2004-04-29           True
# 29  female     Michele Hardin  1984-10-03           True
# 30  female       Denise Moore  1968-04-22           True
# 31    male     William Barker  1977-04-02           True
# 32  female    Kathleen Nelson  1992-02-16           True
# 33    male   Benjamin Hubbard  1972-07-07           True
# 34  female       Robin Chavez  1969-07-01           True
# 35    male      Brian Morales  1970-08-19           True
# 36    male        David Giles  1963-01-13           True
# 37    male       Robert Brown  1974-12-11           True
# 38  female     Jasmine Juarez  1975-04-11           True
# 39  female       Madison Yang  2003-10-07           True
#
#                           languages_spoken  price      education  \
# 0                                [english]     25    high-school
# 1                         [italian, dutch]     36  middle-school
# 2               [chinese, french, english]     34            phd
# 3                              [bulgarian]     46       bachelor
# 4                       [deutsche, french]     30         master
# 5             [deutsche, dutch, bulgarian]     27  middle-school
# 6               [english, chinese, french]     34  middle-school
# 7        [spanish, dutch, french, italian]     33       bachelor
# 8            [bulgarian, english, chinese]     31  middle-school
# 9     [chinese, bulgarian, dutch, english]     37            phd
# 10                   [bulgarian, deutsche]     23    high-school
# 11                             [bulgarian]     23            phd
# 12                [dutch, french, italian]     19       bachelor
# 13                      [chinese, english]     27         master
# 14                       [chinese, french]     40  middle-school
# 15                     [deutsche, chinese]     31  middle-school
# 16            [spanish, bulgarian, french]     32  middle-school
# 17                                 [dutch]     26         master
# 18                        [italian, dutch]     24       bachelor
# 19          [bulgarian, deutsche, english]     35  middle-school
# 20                      [deutsche, french]     43         master
# 21                               [chinese]     26    high-school
# 22                      [chinese, spanish]     25    high-school
# 23           [english, italian, bulgarian]     20  middle-school
# 24             [dutch, italian, bulgarian]     28    high-school
# 25                             [bulgarian]     31            phd
# 26                                 [dutch]     30            phd
# 27                               [italian]     30            phd
# 28                               [spanish]     25  middle-school
# 29                    [bulgarian, chinese]     28         master
# 30             [french, deutsche, english]     27       bachelor
# 31             [deutsche, french, english]     23         master
# 32                     [french, bulgarian]     28            phd
# 33                                [french]     26  middle-school
# 34  [chinese, spanish, bulgarian, italian]     28  middle-school
# 35                       [italian, french]     30         master
# 36                               [spanish]     26            phd
# 37                                 [dutch]     26         master
# 38                               [italian]     28         master
# 39                        [spanish, dutch]     26  middle-school
#
#                                        biography  \
# 0                          Multimedia programmer
# 1                      Education officer, museum
# 2                          Child psychotherapist
# 3               Scientific laboratory technician
# 4                 Equality and diversity officer
# 5                             Purchasing manager
# 6                       Journalist, broadcasting
# 7                            Mental health nurse
# 8                                     Ergonomist
# 9           International aid/development worker
# 10                           Call centre manager
# 11                     Radiographer, therapeutic
# 12                         Aeronautical engineer
# 13                   Industrial/product designer
# 14                Chartered certified accountant
# 15                              Location manager
# 16                                   Tax adviser
# 17                       Communications engineer
# 18                          Community pharmacist
# 19                                  Tree surgeon
# 20                                Engineer, site
# 21                           Surveyor, insurance
# 22                      Administrator, education
# 23                             Freight forwarder
# 24                           Engineer, materials
# 25                       Therapist, occupational
# 26                                Water engineer
# 27                              Paediatric nurse
# 28  Production designer, theatre/television/film
# 29                     Conference centre manager
# 30                      Educational psychologist
# 31                       Engineer, manufacturing
# 32                           Mechanical engineer
# 33                  Designer, exhibition/display
# 34                      Scientist, physiological
# 35                   Civil Service administrator
# 36                                Soil scientist
# 37                         Management consultant
# 38                      Computer games developer
# 39                         Nutritional therapist
#
#                                              keywords  \
# 0                                           [museums]
# 1                    [cinema, rafting, history, wine]
# 2                             [food, archeology, art]
# 3                         [countryside, rafting, art]
# 4                       [countryside, tracking, beer]
# 5                                                  []
# 6                               [rafting, art, sport]
# 7                   [museums, art, countryside, wine]
# 8                         [literature, cinema, music]
# 9                                           [museums]
# 10     [cinema, rafting, sport, museums, countryside]
# 11                            [cinema, beer, rafting]
# 12                               [sport, music, beer]
# 13                          [sport, archeology, beer]
# 14                                          [museums]
# 15                [music, food, tracking, archeology]
# 16                         [countryside, music, beer]
# 17                                 [wine, sport, art]
# 18                                             [food]
# 19                                                 []
# 20                           [rafting, museums, food]
# 21                                           [cinema]
# 22  [history, countryside, cinema, literature, music]
# 23                                         [tracking]
# 24                                                 []
# 25                                       [literature]
# 26                          [tracking, beer, museums]
# 27                                [countryside, beer]
# 28     [food, rafting, museums, music, art, tracking]
# 29                 [archeology, literature, tracking]
# 30                                            [music]
# 31                         [music, countryside, food]
# 32                                [archeology, music]
# 33             [beer, music, countryside, archeology]
# 34                                                 []
# 35                                            [music]
# 36                                                 []
# 37                                                 []
# 38                                                 []
# 39                                          [history]
#
#                                      current_location  experience
# 0   {'lat': 40.342693584880706, 'lon': 18.16438078...           8
# 1   {'lat': 40.3367551413547, 'lon': 18.1569120995...          26
# 2   {'lat': 40.362447049660204, 'lon': 18.14225129...          31
# 3   {'lat': 40.36584086550253, 'lon': 18.183002910...          16
# 4   {'lat': 40.354724889812935, 'lon': 18.20308322...           5
# 5   {'lat': 40.35854623058413, 'lon': 18.183459879...           3
# 6   {'lat': 40.35774331848761, 'lon': 18.163273185...           3
# 7   {'lat': 40.365193043282794, 'lon': 18.18548169...           2
# 8   {'lat': 40.35265552781134, 'lon': 18.151723396...          42
# 9   {'lat': 40.33774657696426, 'lon': 18.182064664...          11
# 10  {'lat': 40.36612881009787, 'lon': 18.182042843...          28
# 11  {'lat': 40.367394960036485, 'lon': 18.17553586...           5
# 12  {'lat': 40.34268462008425, 'lon': 18.187542175...           5
# 13  {'lat': 40.35377358678542, 'lon': 18.174728239...          14
# 14  {'lat': 40.353069674191346, 'lon': 18.17755576...          21
# 15  {'lat': 40.35272705494921, 'lon': 18.165705019...          24
# 16  {'lat': 40.32347428820915, 'lon': 18.164571467...           7
# 17  {'lat': 40.36624424923941, 'lon': 18.174443383...          16
# 18  {'lat': 40.362871505646005, 'lon': 18.18292777...          37
# 19  {'lat': 40.339915788807765, 'lon': 18.18379781...           6
# 20  {'lat': 40.357612936236265, 'lon': 18.16907898...          35
# 21  {'lat': 40.342846292499104, 'lon': 18.16089760...          11
# 22  {'lat': 40.36846436096489, 'lon': 18.171263566...          15
# 23  {'lat': 40.364408581391295, 'lon': 18.16428124...          22
# 24  {'lat': 40.32998981194129, 'lon': 18.175342312...          18
# 25  {'lat': 40.36710284805045, 'lon': 18.179956956...           4
# 26  {'lat': 40.37981446263931, 'lon': 18.178854600...          45
# 27  {'lat': 40.3457074414046, 'lon': 18.1747654675...           2
# 28  {'lat': 40.35079556972286, 'lon': 18.181927024...           1
# 29  {'lat': 40.35465462623879, 'lon': 18.172666005...          20
# 30  {'lat': 40.361047668976795, 'lon': 18.18633484...          25
# 31  {'lat': 40.339171732936364, 'lon': 18.16792590...           7
# 32  {'lat': 40.343414579847, 'lon': 18.18565562805...          10
# 33  {'lat': 40.34424559835338, 'lon': 18.174907197...          29
# 34  {'lat': 40.38198340911851, 'lon': 18.173378831...          34
# 35  {'lat': 40.36699713437984, 'lon': 18.165786470...          14
# 36  {'lat': 40.358649720289904, 'lon': 18.16378056...          11
# 37  {'lat': 40.3604075695112, 'lon': 18.1615738690...           4
# 38  {'lat': 40.36497247240833, 'lon': 18.173581152...          31
# 39  {'lat': 40.35901486939172, 'lon': 18.166553513...           2

# %%
tourist_df = pd.DataFrame(tourists)
tourist_df
# Out:
#                 languages                       keywords
# 0      [italian, english]                [cinema, music]
# 1               [chinese]                         [beer]
# 2    [bulgarian, spanish]       [history, museums, beer]
# 3       [deutsche, dutch]  [tracking, literature, music]
# 4               [spanish]                [tracking, art]
# ..                    ...                            ...
# 195           [bulgarian]                             []
# 196     [french, spanish]             [tracking, cinema]
# 197    [chinese, spanish]       [music, literature, art]
# 198             [italian]                             []
# 199             [spanish]                             []
#
# [200 rows x 2 columns]

# %%
rating_df = pd.DataFrame(ratings)

# %%
rating_df
# Out:
#        0   1    2
# 0      0   7  4.0
# 1      0   3  3.0
# 2      1  23  5.0
# 3      2   4  4.0
# 4      2  27  4.0
# ..   ...  ..  ...
# 351  197  23  2.0
# 352  198  35  4.0
# 353  199  18  4.0
# 354  199  21  4.0
# 355  199  34  2.0
#
# [356 rows x 3 columns]

# %%
tourist_df.to_csv("Data/tourists_{:d}.csv".format(n_tourists), index=True, sep=';')
guide_df.to_csv("Data/guides_{:d}.csv".format(n_guides), index=True, sep=';')
rating_df.to_csv('Data/ratings_{:d}_{:d}.csv'.format(n_tourists,n_guides), index=False, sep=';')
